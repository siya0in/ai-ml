# %%
import pandas as pd
df=pd.read_csv("output3.csv")

# %%
'''
fig, ax1 = plt.subplots(figsize=(20, 8))

df['average insect count'] = df['mean / 10 min'] * 4  # Multiply by 10 instead of 20

# Plot the first set of data (Temp Mean, Humidity Mean, Average Insect Count)
ax1.plot(df['timestamp'], df['Dew Point, *C, WEASN17 Osmia 2023'], color='red', label='Dew Point')
ax1.plot(df['timestamp'], df['Gust Speed, m/s, WEASN17 Osmia 2023'], color='blue', label='Gust Speed')
ax1.plot(df['timestamp'], df['average insect count'], color='green', label='Average Insect Count')  # Use 'average insect count' instead of 'mean / 10 min'
ax1.plot(df['timestamp'], df[''], color='', label='Average Insect Count') 
ax1.plot(df['timestamp'], df[''], color='', label='Average Insect Count') 

# Set labels and title for the first y-axis
ax1.set_xlabel('Time')
ax1.set_ylabel('Temp Mean / Humidity Mean / Average Insect Count')

# Create a second y-axis
ax2 = ax1.twinx()

# Plot the second set of data (Light Mean)
ax2.plot(df['timestamp'], df['light_mean'], color='orange', label='Light Mean')

# Set label for the second y-axis
ax2.set_ylabel('Light Mean')
ax1.set_xticks(df['timestamp'][::24])



# Display the legend
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Show the plot
plt.show()
'''
import matplotlib.pyplot as plt
# Prepare the data
x = df['timestamp']
y = df[['Dew Point, *C, WEASN17 Osmia 2023', 'Gust Speed, m/s, WEASN17 Osmia 2023', 'RH, %, WEASN17 Osmia 2023 Air humidity', 'average insect count','Temperature, *C, WEASN17 Osmia 2023 AIr temperature','Solar Radiation, W/m^2, WEASN17 Osmia 2023 Radiation']]

# Create the figure and axes

fig, ax = plt.subplots(figsize=(20, 8))

# Plot the regression lines for each variable
for column in y.columns:
    ax.plot(x, y[column], label=column)

# Set the x-axis label and rotate the tick labels
ax.set_xlabel('Time')
plt.xticks(rotation=45)

# Set the y-axis label
ax.set_ylabel('Attributes')

# Set the title of the plot
ax.set_title('Regression Line')

# Add a legend
ax.legend()

# Show the plot
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(20, 8))

df['average insect count'] = df['average insect count'] * 4  # Multiply by 10 instead of 20
df['Gust Speed, m/s, WEASN17 Osmia 2023']=df['Gust Speed, m/s, WEASN17 Osmia 2023']*10
# Plot the first set of data (Temp Mean, Humidity Mean, Average Insect Count)
ax1.plot(df['timestamp'], df['Dew Point, *C, WEASN17 Osmia 2023'], color='blue', label='Dew Point')
ax1.plot(df['timestamp'], df['Gust Speed, m/s, WEASN17 Osmia 2023'], color='orange', label='Gust Speed')
ax1.plot(df['timestamp'], df['average insect count'], color='red', label='Average Insect Count')  # Use 'average insect count' instead of 'mean / 10 min'
ax1.plot(df['timestamp'], df['RH, %, WEASN17 Osmia 2023 Air humidity'], color='green', label='Relative Humidity')
ax1.plot(df['timestamp'], df['Temperature, *C, WEASN17 Osmia 2023 AIr temperature'], color='purple', label='Temperature')


# Set labels and title for the first y-axis
ax1.set_xlabel('TimeStamp')
ax1.set_ylabel('Temp/Humidity/Solar Radition/insect count')

# Create a second y-axis
ax2 = ax1.twinx()

# Plot the second set of data (Light Mean)
ax2.plot(df['timestamp'], df['Solar Radiation, W/m^2, WEASN17 Osmia 2023 Radiation'], color='brown', label='Solar Radiation')

# Set label for the second y-axis
ax2.set_ylabel('Light Mean')
ax1.set_xticks(df['timestamp'][::26])



# Display the legend
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Show the plot
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(20, 8))

df['average insect count'] = df['average insect count'] * 4  # Multiply by 10 instead of 20
df['Gust Speed, m/s, WEASN17 Osmia 2023']=df['Gust Speed, m/s, WEASN17 Osmia 2023']*10
# Plot the first set of data (Temp Mean, Humidity Mean, Average Insect Count)
ax1.plot(df['timestamp'], df['Dew Point, *C, WEASN17 Osmia 2023'], color='blue', label='Dew Point')
ax1.plot(df['timestamp'], df['Gust Speed, m/s, WEASN17 Osmia 2023'], color='orange', label='Gust Speed')
ax1.plot(df['timestamp'], df['average insect count'], color='red', label='Average Insect Count')  # Use 'average insect count' instead of 'mean / 10 min'
ax1.plot(df['timestamp'], df['Temperature, *C, WEASN17 Osmia 2023 AIr temperature'], color='purple', label='Temperature')


# Set labels and title for the first y-axis
ax1.set_xlabel('TimeStamp')
ax1.set_ylabel('Temp/Humidity/Solar Radition/insect count')

# Create a second y-axis
ax2 = ax1.twinx()

# Plot the second set of data (Light Mean)
ax2.plot(df['timestamp'], df['RH, %, WEASN17 Osmia 2023 Air humidity'], color='green', label='Relative Humidity')

ax2.plot(df['timestamp'], df['Solar Radiation, W/m^2, WEASN17 Osmia 2023 Radiation'], color='brown', label='Solar Radiation')

# Set label for the second y-axis
ax2.set_ylabel('Light Mean')
ax1.set_xticks(df['timestamp'][::26])



# Display the legend
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Show the plot
plt.show()
